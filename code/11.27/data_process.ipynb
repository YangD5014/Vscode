# %%
import numpy as np
import pandas as pd
data = pd.read_csv(r'dipole.dat',delim_whitespace=True)
data = data.drop(index=0,axis=0)
#print(data)
list_ = []
column_1 =data.iloc[:,0].to_list()
column_2 =data.iloc[:,1].to_list()
column_3 =data.iloc[:,2].to_list()
column_4 =data.iloc[:,3].to_list()
list_.extend(column_1)
list_.extend(column_2)
list_.extend(column_3)
list_.extend(column_4)

# %%
list_
# Out:
# [0.000488281,
#  0.000732422,
#  0.000976562,
#  0.0012207,
#  0.00146484,
#  0.00170898,
#  0.00195312,
#  0.00219727,
#  0.00244141,
#  0.00268555,
#  0.00292969,
#  0.00317383,
#  0.00341797,
#  0.00366211,
#  0.00390625,
#  0.00415039,
#  0.00439453,
#  0.00463867,
#  0.00488281,
#  0.00512695,
#  0.00537109,
#  0.00561523,
#  0.00585938,
#  0.00610352,
#  0.00634766,
#  0.0065918,
#  0.00683594,
#  0.00708008,
#  0.00732422,
#  0.00756836,
#  0.0078125,
#  0.00805664,
#  0.00830078,
#  0.00854492,
#  0.00878906,
#  0.0090332,
#  0.00927734,
#  0.00952148,
#  0.00976562,
#  0.0100098,
#  0.0102539,
#  0.010498,
#  0.0107422,
#  0.0109863,
#  0.0112305,
#  0.0114746,
#  0.0117188,
#  0.0119629,
#  0.012207,
#  0.0124512,
#  0.0126953,
#  0.0129395,
#  0.0131836,
#  0.0134277,
#  0.0136719,
#  0.013916,
#  0.0141602,
#  0.0144043,
#  0.0146484,
#  0.0148926,
#  0.0151367,
#  0.0153809,
#  0.015625,
#  0.0158691,
#  0.0161133,
#  0.0163574,
#  0.0166016,
#  0.0168457,
#  0.0170898,
# ...

# %%
data.columns
# Out:
# Index([' cycle              dipMom          dipAccel          totalnorm'], dtype='object')
